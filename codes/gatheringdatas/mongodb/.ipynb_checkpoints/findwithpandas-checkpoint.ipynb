# %%
# %conda install pymongo

# %%
import pymongo as mg
import pandas as pd

# %%
mg.__version__
# Out:
# '3.12.0'

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['db_NHIS']

# %%
collection = database['NSC2_BND']

# %%
cursor = collection.find({})

# %%
list_BND = list(cursor)

# %%
list_BND
# Out:
# [{'_id': ObjectId('64d2fd0df4e564d9e04add10'),
#   'RN_INDI': 294364,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200707,
#   'COD1': 'T08-T14',
#   'COD2': 'W00-W19'},
#  {'_id': ObjectId('64d2fd0df4e564d9e04add11'),
#   'RN_INDI': 646257,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200805,
#   'COD1': 'A15-A19'},
#  {'_id': ObjectId('64d2fd0df4e564d9e04add12'),
#   'RN_INDI': 733575,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201309,
#   'COD1': 'G30'},
#  {'_id': ObjectId('64d2fd0df4e564d9e04add13'),
#   'RN_INDI': 966199,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201409,
#   'COD1': 'J69'},
#  {'_id': ObjectId('64d2fd0df4e564d9e04add14'),
#   'RN_INDI': 972598,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201205,
#   'COD1': 'C44'},
#  {'_id': ObjectId('64d2fd0df4e564d9e04add15'),
#   'RN_INDI': 979888,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201101,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd0df4e564d9e04add16'),
#   'RN_INDI': 991645,
#   'BTH_YYYY': '1921LE',
# ...

# %%
df_BND = pd.DataFrame(list(cursor))

# %%
df_BND
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_BND.to_csv('./NSC2_BND.csv')

# %%
collection2 = database['NSC2_BNC_V2_1']

# %%
cursor2 = collection2.find({})

# %%
list_BND2 = list(cursor2)

# %%
list_BND2
# Out:
# [{'_id': ObjectId('64d31dc39438cbf6658ae849'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d31dc39438cbf6658ae84a'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d31dc39438cbf6658ae84b'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d31dc39438cbf6658ae84c'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d31dc39438cbf6658ae84d'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d31dc39438cbf6658ae84e'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
# ...

# %%
df_BND2 = pd.DataFrame(list(cursor2))

# %%
df_BND2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_BND2.to_csv('./NSC2_BNC_V2_1.csv')

# %%
collection3 = database['NSC2_D20']

# %%
cursor3 = collection3.find({})

# %%
list_BND3 = list(cursor3)

# %%
list_BND3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 list_BND3
#
# NameError: name 'list_BND3' is not defined

# %%
df_BND3 = pd.DataFrame(list(cursor3))

# %%
df_BND3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_BND3.to_csv('./NSC2_D20.csv')
